# %%
# import pandas as pd
# !pwd
# Out:
# /mnt/notebooks

# %%
jdbcDF1 = spark.read \
    .format("jdbc") \
    .option("driver", "com.facebook.presto.jdbc.PrestoDriver") \
    .option("url", "jdbc:presto://presto:8080/hive/proyectos") \
    .option("user", "hive") \
    .option("dbtable", "hue__tmp_customers1") \
    .load()

# %%
jdbcDF2 = spark.read \
    .format("jdbc") \
    .option("driver", "com.facebook.presto.jdbc.PrestoDriver") \
    .option("url", "jdbc:presto://presto:8080/hive/proyectos") \
    .option("user", "hive") \
    .option("dbtable", "hue__tmp_customers2") \
    .load()

# %%
concatenatedDF = jdbcDF1.union(jdbcDF2)
concatenatedDF.toPandas()
# Exportar el DataFrame concatenado a un archivo CSV
# concatenatedDF.write \
#     .option("header", "true") \
#     .csv("/mnt/notebooks/Salida/csv_directory.csv")

# concatenatedDF.coalesce(1).write \
#     .option("header", "true") \
#     .csv("/mnt/notebooks/Salida/")
# Out:
#        index      customer id  first name  last name          company  \
# 0        NaN      Customer Id  First Name  Last Name          Company
# 1        1.0  DD37Cf93aecA6Dc      Sheryl     Baxter  Rasmussen Group
# 2        2.0  1Ef7b82A4CAAD10     Preston     Lozano      Vega-Gentry
# 3        3.0  6F94879bDAfE5a6         Roy      Berry    Murillo-Perry
# 4        4.0  5Cef8BFA16c5e3c       Linda      Olsen       "Dominguez
# ...      ...              ...         ...        ...              ...
# 1097   996.0  FbcCaF483aFaFAE       Diana     Monroe      Bass-Wilson
# 1098   997.0  979c4D58Ae9a9cc       Jerry    Morales       Pratt-King
# 1099   998.0  D0DcF6a4BcefCc8      Tracie      Floyd            "Holt
# 1100   999.0  90EE9CbbDa374E9        Paul     Barnes           "Brown
# 1101  1000.0  51732B5b2328015     Dominic      Duran       Durham LLC
#
#                         city  \
# 0                       City
# 1               East Leonard
# 2          East Jimmychester
# 3              Isabelborough
# 4      Mcmillan and Donovan"
# ...                      ...
# 1097       Lake Jacksonmouth
# 1098    South Dominiquemouth
# 1099     Wilson and Shields"
# 1100      Oliver and Haynes"
# 1101              East Wendy
#
#                                                 country  \
# 0                                               Country
# 1                                                 Chile
# 2                                              Djibouti
# 3                                   Antigua and Barbuda
# 4                                            Bensonview
# ...                                                 ...
# 1097                                          Guatemala
# 1098                                            Georgia
# 1099                                    East Chloeshire
# 1100                                        South Shane
# 1101  British Indian Ocean Territory (Chagos Archipe...
#
#                     phone 1                 phone 2  \
# 0                   Phone 1                 Phone 2
# 1              229.077.5154        397.884.0519x718
# 2                5153435776        686-620-1820x944
# 3           +1-539-402-0259     (496)978-3969x58947
# 4        Dominican Republic  001-808-617-6467x12895
# ...                     ...                     ...
# 1097  +1-171-715-9766x54993     (489)413-7296x32807
# 1098       132.253.8501x097   +1-301-292-8363x80270
# 1099        Solomon Islands              1193982387
# 1100                Finland    +1-537-466-3245x3699
# 1101        +1-278-758-4331        814-860-0941x057
#
#                            email             subscription date  \
# 0                          Email             Subscription Date
# 1       zunigavanessa@smith.info                    2020-08-24
# 2                vmata@colon.com                    2021-04-23
# 3            beckycarr@hogan.com                    2020-03-25
# 4                +1-813-324-8756   stanleyblackwell@benson.org
# ...                          ...                           ...
# 1097  cassidymercado@bonilla.com                    2022-01-09
# 1098     gavin13@logan-downs.com                    2021-08-21
# 1099               (482)926-8966        lowehailey@oconnor.org
# 1100                791-835-9075  hodgeseddie@hardin-wells.com
# 1101      owarner@velasquez.info                    2021-12-09
#
#                          website
# 0                        Website
# 1     http://www.stephenson.com/
# 2          http://www.hobbs.com/
# 3       http://www.lawrence.com/
# 4                     2020-06-02
# ...                          ...
# 1097          http://castro.net/
# 1098     https://www.braun.info/
# 1099                  2020-04-22
# 1100                  2021-03-12
# 1101         http://www.cox.com/
#
# [1102 rows x 12 columns]

# %%
# !ls /mnt/notebooks/Salida
# concatenatedDF.show()

# %%
jdbcDF2.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-dd5bf1461f26> in <module>()
# ----> 1 jdbcDF2.show()
#
# AttributeError: 'DataFrameReader' object has no attribute 'show'

# %%
dataframe_mysql = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:mysql://database/employees") \
    .option("driver", "com.mysql.jdbc.Driver") \
    .option("dbtable", "employees") \
    .option("user", "root") \
    .option("password", "secret") \
    .load()

# %%
# dataframe_mysql.show()
dataframe_mysql.toPandas()
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
dataframe_mysql.write.parquet("mysql")

# %%
df = spark.read.parquet("mysql")

# %%
df.show()
# Out:
# +------+----------+----------+-----------+------+----------+
# |emp_no|birth_date|first_name|  last_name|gender| hire_date|
# +------+----------+----------+-----------+------+----------+
# | 10001|1953-09-02|    Georgi|    Facello|     M|1986-06-26|
# | 10002|1964-06-02|   Bezalel|     Simmel|     F|1985-11-21|
# | 10003|1959-12-03|     Parto|    Bamford|     M|1986-08-28|
# | 10004|1954-05-01| Chirstian|    Koblick|     M|1986-12-01|
# | 10005|1955-01-21|   Kyoichi|   Maliniak|     M|1989-09-12|
# | 10006|1953-04-20|    Anneke|    Preusig|     F|1989-06-02|
# | 10007|1957-05-23|   Tzvetan|  Zielinski|     F|1989-02-10|
# | 10008|1958-02-19|    Saniya|   Kalloufi|     M|1994-09-15|
# | 10009|1952-04-19|    Sumant|       Peac|     F|1985-02-18|
# | 10010|1963-06-01| Duangkaew|   Piveteau|     F|1989-08-24|
# | 10011|1953-11-07|      Mary|      Sluis|     F|1990-01-22|
# | 10012|1960-10-04|  Patricio|  Bridgland|     M|1992-12-18|
# | 10013|1963-06-07| Eberhardt|     Terkki|     M|1985-10-20|
# | 10014|1956-02-12|     Berni|      Genin|     M|1987-03-11|
# | 10015|1959-08-19|  Guoxiang|  Nooteboom|     M|1987-07-02|
# | 10016|1961-05-02|  Kazuhito|Cappelletti|     M|1995-01-27|
# | 10017|1958-07-06| Cristinel|  Bouloucos|     F|1993-08-03|
# | 10018|1954-06-19|  Kazuhide|       Peha|     F|1987-04-03|
# | 10019|1953-01-23|   Lillian|    Haddadi|     M|1999-04-30|
# | 10020|1952-12-24|    Mayuko|    Warwick|     M|1991-01-26|
# +------+----------+----------+-----------+------+----------+
# only showing top 20 rows
